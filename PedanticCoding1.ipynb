# %%
order = input("What is your order: ")
if(order == 'Cheese Burger Deluxe'):
    question = input("Would you like to add fries and drink to your CBD?")
    if (question == 'Yes'):
        print("Cheese Burger Deluxe with additional fries and drinks.")
    else:
        print("Cheese Burger Deluxe with sundae.")
else:
    print(order)
# Out:
# What is your order:  Cheese Burger Deluxe
# Would you like to add fries and drink to your CBD? Yes
# Cheese Burger Deluxe with additional fries and drinks.
